# %%
import pandas as pd

# %%
df = pd.read_csv("./dataset.csv", delimiter=",")

# %%
df = df[:3000]

# %%
df
# Out:
#       CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0            2.0  30.0  Female    39.0             14.0            5.0
# 1            3.0  65.0  Female    49.0              1.0           10.0
# 2            4.0  55.0  Female    14.0              4.0            6.0
# 3            5.0  58.0    Male    38.0             21.0            7.0
# 4            6.0  23.0    Male    32.0             20.0            5.0
# ...          ...   ...     ...     ...              ...            ...
# 2995      3004.0  34.0    Male    17.0             23.0            2.0
# 2996      3005.0  18.0    Male    28.0             10.0            8.0
# 2997      3006.0  65.0  Female     4.0             28.0            8.0
# 2998      3007.0  48.0  Female    47.0              2.0            8.0
# 2999      3008.0  23.0  Female    55.0             22.0            5.0
#
#       Payment Delay Subscription Type Contract Length  Total Spend  \
# 0              18.0          Standard          Annual        932.0
# 1               8.0             Basic         Monthly        557.0
# 2              18.0             Basic       Quarterly        185.0
# 3               7.0          Standard         Monthly        396.0
# 4               8.0             Basic         Monthly        617.0
# ...             ...               ...             ...          ...
# 2995           28.0           Premium          Annual        284.0
# 2996           20.0          Standard         Monthly        898.0
# 2997           13.0           Premium          Annual        564.0
# 2998           24.0             Basic       Quarterly        213.0
# 2999            8.0           Premium         Monthly        271.0
#
#       Last Interaction  Churn
# 0                 17.0    1.0
# 1                  6.0    1.0
# 2                  3.0    1.0
# 3                 29.0    1.0
# 4                 20.0    1.0
# ...                ...    ...
# 2995              11.0    1.0
# 2996               9.0    1.0
# 2997              19.0    1.0
# 2998              30.0    1.0
# 2999              20.0    1.0
#
# [3000 rows x 12 columns]

# %%
y = df['Churn']
x = df.drop('Churn', axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %% [markdown]
# #

# %%
numeric_features = ['Age', 'Tenure', 'Usage Frequency', 'Support Calls',
                    'Payment Delay', 'Total Spend', 'Last Interaction']
categorical_features = ['Gender', 'Subscription Type', 'Contract Length']

# %% [markdown]
# # PreProcess the features

# %%
preprocessor = ColumnTransformer(
        transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])

# %% [markdown]
# # Create Pipeline for Model using SVM Kernels

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', SVC(kernel='rbf', C=1, gamma='scale'))  # You can replace SVC() with LogisticRegression() etc.
])

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Age', 'Tenure',
#                                                    'Usage Frequency',
#                                                    'Support Calls',
#                                                    'Payment Delay',
#                                                    'Total Spend',
#                                                    'Last Interaction']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Gender',
#                                                    'Subscription Type',
#                                                    'Contract Length'])])),
#                 ('classifier', SVC(C=1))])

# %%
y_pred = pipeline.predict(x_test)

# %%
y_pred
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test, y_pred))
# Out:
# 0.9625

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        90
#          1.0       0.96      1.00      0.98      2310
#
#     accuracy                           0.96      2400
#    macro avg       0.48      0.50      0.49      2400
# weighted avg       0.93      0.96      0.94      2400
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Test Data

# %%
test_df =
